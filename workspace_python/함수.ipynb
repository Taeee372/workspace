# %%
def sayHello():
  print(1)
  print(2)

# %%
sayHello()
# Out:
# 1
# 2

# %%
def getSum(a, b):
  print(a + b)
  return a + b

# %%
result = getSum(10, 20)
print(result)
# Out:
# 30
# 30

# %%
# 파이썬의 함수는 return 데이터를 여러 개 가질 수 있음
def getNumber():
  return 10, 20, 30

# %%
r1, r2, r3 = getNumber()
print(r1, r2, r3)
# Out:
# 10 20 30

# %%
# 파이썬은 매개변수에 데이터를 전달할 때 매개변수명을 활용할 수 있음
def printInfo(name, age):
  print(f'이름은 {name}이고, 나이는 {age}')

# %%
printInfo('kim', 20)
printInfo(name = 'kim', age = 20)
printInfo(age = 30, name = 'lee')
# Out:
# 이름은 kim이고, 나이는 20
# 이름은 kim이고, 나이는 20
# 이름은 lee이고, 나이는 30
